# %% [markdown]
# # Single line comment

# %%
letter = 'P'

# %%
letter
# Out:
# 'P'

# %%
print(len(letter))
# Out:
# 1

# %%
greeting = 'Hello, World!'

# %%
print(greeting)
# Out:
# Hello, World!

# %%
print(len(greeting))
# Out:
# 13

# %%
sentence = "I hope you are enjoying 30 days of python challenge"

# %%
print(sentence)
# Out:
# I hope you are enjoying 30 days of python challenge

# %% [markdown]
# # Multiline String

# %%
multiline_string = '''I am teacher and enjoy teaching. 
I did'nt find anything as rewarding as empowering people.
That is why I created 30 days of python.'''

# %%
print(multiline_string)
# Out:
# I am teacher and enjoy teaching.
# I did'nt find anything as rewarding as empowering people.
# That is why I created 30 days of python.

# %% [raw]
# # Another way of doing the same thing

# %%
multiline_string = """I am teacher and enjoy teaching. 
I did'nt find anything as rewarding as empowering people.
That is why I created 30 days of python."""

# %%
print(multiline_string)
# Out:
# I am teacher and enjoy teaching.
# I did'nt find anything as rewarding as empowering people.
# That is why I created 30 days of python.

# %% [markdown]
# # String Concatenation

# %%
first_name ='Rakesh'
last_name = 'Pawade'
space = ' '

# %%
full_name = first_name + space + last_name

# %%
print(full_name)
# Out:
# Rakesh Pawade

# %% [markdown]
# ## Checking length of a String using len() builtin function

# %%
print(len(first_name))
print(len(last_name))
print(len(first_name) > len(last_name))
print(len(full_name))
# Out:
# 6
# 6
# False
# 13

# %% [markdown]
# ## Unpacking character

# %%
language = 'Python'

# %%
a,b,c,d,e,f = language

# %%
print(a)
print(b)
print(c)
print(d)
print(e)
print(f)
# Out:
# P
# y
# t
# h
# o
# n

# %% [markdown]
# ## Accessing characters in string by index

# %%
language = 'Python'

# %%
first_letter = language[0]

# %%
print(first_letter)
# Out:
# P

# %%
second_letter =language[1]
print(second_letter)
# Out:
# y

# %%
last_index = len(language) - 1
last_letter = language[last_index]
print(last_letter)
# Out:
# n

# %% [markdown]
# ## If we want to start from right end we can use negative indexing.

# %%
language = 'Python'

# %%
last_letter = language[-1]
print(last_letter)
# Out:
# n

# %%
second_last = language[-2]
print(second_last)
# Out:
# o

# %% [markdown]
# ## Slicing

# %%
language = 'Python'

# %%
first_three = language[0:3] # start at zero index and upto 3 but not include 3
print(first_three)
# Out:
# Pyt

# %%
last_three = language[3:6]
print(last_three)
# Out:
# hon

# %% [raw]
# # another way

# %%
language = 'Python'

# %%
last_three = language1[-3:]
print(last_three)
# Out:
# hon

# %%
last_three = language[3:]
print(last_three)
# Out:
# hon

# %% [markdown]
# ## Skipping character while python strings

# %%
language = 'Python'

# %%
pto = language[0:6:2]

# %%
print(pto)
# Out:
# Pto

# %% [markdown]
# ## Escape sequence

# %%
print('I hope every one enjoying the python challenge.\nDo you ?')
# Out:
# I hope every one enjoying the python challenge.
# Do you ?

# %%
print('Day\tTopics\tExercise')
# Out:
# Day	Topics	Exercise

# %%
print('Day 1\t3\t5')
# Out:
# Day 1	3	5

# %%
print('Day 2\t3\t5')
# Out:
# Day 2	3	5

# %%
print('Day 3\t3\t5')
# Out:
# Day 3	3	5

# %%
print('Day 4\t3\t5')
# Out:
# Day 4	3	5

# %%
print('This is back slash symbol (\\)') #how to write back slash
# Out:
# This is back slash symbol (\)

# %%
print('In every programming language it starts with \"Hello,World!\"')
# Out:
# In every programming language it starts with "Hello,World!"

# %% [markdown]
# ## string method

# %% [markdown]
# ### capitalize(): Converts the first character the string to Capital Letter

# %%
challenge = 'thirty days of python'
print(challenge.capitalize())
# Out:
# Thirty days of python

# %% [markdown]
# ### count(): returns occuring of substring in string,count(substring, start=..,end=..)

# %%
challenge = 'thirty days of python'
print(len(challenge))
print(challenge.count('y'))
print(challenge.count('y',7,14))
print(challenge.count('th'))
# Out:
# 21
# 3
# 1
# 2

# %% [markdown]
# ### endswith(): Checks if a string ends with a specified ending

# %%
challenge = 'thirty days of python'
print(challenge.endswith('on'))
print(challenge.endswith('tion'))
# Out:
# True
# False

# %% [markdown]
# ### expandtabs(): Replaces tab character with spaces,default tab size is 8.It takes tab size argument

# %%
challenge = 'thirty\tdays\tof\tpython'
print(challenge.expandtabs())
print(challenge.expandtabs(10))
# Out:
# thirty  days    of      python
# thirty    days      of        python

# %% [markdown]
# ### find(): Returns the index of first occurance of substring

# %%
challenge = 'thirty days of python'
print(challenge.find('y'))
print(challenge.find('th'))
# Out:
# 5
# 0

# %% [markdown]
# ### format(): format string into nicer output

# %%
first_name = 'Rakesh'
last_name = 'Pawade'
job = 'Data Analyst'
country = 'India'
sentence = 'I am {} {}. I am a {}.I live in {}.'.format(first_name,last_name,job,country)
print(sentence)
# Out:
# I am Rakesh Pawade. I am a Data Analyst.I live in India.

# %%
radius = 10
pi =3.14
area = pi*radius**2
result = 'The area of circle with {} is {}'.format(str(radius),str(area))
print(result)
# Out:
# The area of circle with 10 is 314.0

# %% [markdown]
# ### index(): Returns the index of substring

# %%
challenge = 'thirty days of python'
print(challenge.find('d'))
print(challenge.find('py'))
# Out:
# 7
# 15

# %% [markdown]
# ### isalnum(): checks alphanumeric char

# %%
challenge = 'thirty days of python'
print(challenge.isalnum())
# Out:
# False

# %%
challenge = '30daysofpython'
print(challenge.isalnum())
# Out:
# True

# %% [markdown]
# ### isalpha():check if all char are alphabets

# %%
challenge = 'thirty days of python' #output false bcoz space count as numeric
print(challenge.isalpha())
# Out:
# False

# %%
challenge = 'thirtydaysofpython'
print(challenge.isalpha())
# Out:
# True

# %%
num = '123'
print(num.isalpha())
# Out:
# False

# %% [markdown]
# ### isdecimal(): checks decimal char

# %%
num = '10'
print(num.isdecimal())
# Out:
# True

# %%
num = '10.5'
print(num.isdecimal())
# Out:
# False

# %% [markdown]
# ## isdigit():check digit char

# %%
challenge = 'thirty'
print(challenge.isdigit())
# Out:
# False

# %%
challenge = '30'
print(challenge.isdigit())
# Out:
# True

# %% [markdown]
# ### isidentifier(): checks for valid identifier means it check if a string is a valid variable name

# %%
challenge ='30daysofpython'
print(challenge.isidentifier())
# Out:
# False

# %%
challenge = 'thirty_days_of_python'
print(challenge.isidentifier())
# Out:
# True

# %% [markdown]
# ### islower():check if all alphabets in a string are lowercase

# %%
challenge = 'thirty days of python'
print(challenge.islower())
# Out:
# True

# %%
challenge = 'Thirty days of python'
print(challenge.islower())
# Out:
# False

# %% [markdown]
# ### isupper(): returns if all char are uppercase char

# %%
challenge = 'thirty days of python'
print(challenge.isupper())
# Out:
# False

# %%
challenge = 'THIRTY DAYS OF PYTHON'
print(challenge.isupper())
# Out:
# True

# %% [markdown]
# ### isnumeric():check numeric char

# %%
num = '10'
print(num.isnumeric())
print('ten'.isnumeric())
# Out:
# True
# False

# %% [markdown]
# ### join(): return a concatenated  string

# %%
web_tech = ['HTML','CSS','JavaScript','React']
result = '#, '.join(web_tech)
print(result)
# Out:
# HTML#, CSS#, JavaScript#, React

# %% [markdown]
# ### strip(): removes both leading and tailing char

# %%
challenge = ' thirty days of python '
print(challenge.strip('y'))
# Out:
#  thirty days of python

# %% [markdown]
# ### replace(): replaces substring inside

# %%
challenge = 'thirty days of python'
print(challenge.replace('python','coding'))
# Out:
# thirty days of coding

# %% [markdown]
# ### split():split string from left

# %%
challenge = 'thirty days of python'
print(challenge.split())
# Out:
# ['thirty', 'days', 'of', 'python']

# %% [markdown]
# ### title():returns a title cased string

# %%
challenge = 'thirty days of python'
print(challenge.title())
# Out:
# Thirty Days Of Python

# %% [markdown]
# ### swapcase():checks if string start with the specified string

# %%
challenge = 'thirty days of python'
print(challenge.swapcase())
# Out:
# THIRTY DAYS OF PYTHON

# %%
challenge = 'Thirty Days Of Python'
print(challenge.swapcase())
# Out:
# tHIRTY dAYS oF pYTHON

# %% [markdown]
# ### startwith():check if string start with the specified string

# %%
challenge = 'thirty days of python'
print(challenge.startswith('thirty'))
# Out:
# True

# %%
challenge = '30 days of python'
print(challenge.startswith('thirty'))
# Out:
# False
